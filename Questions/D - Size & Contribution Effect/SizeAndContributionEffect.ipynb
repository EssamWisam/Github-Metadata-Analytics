# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="yellow"> <h1> Size </font> & Contribution Effect </h1>
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Stating Questions </h2> </font>
# </span>

# %% [markdown]
# <span style="font-family:Avenir; font-size:1.4em;">
# What is the average size of repositories over time for the top 3 programming languages in terms of pull requests
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       This question is answerable and it's interesting.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       There is no existent answer for such question. It reflects the relationship between contriubtions and size of the repository.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Both match!
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Exploratory Data Analytics</h2> </font>
# </span>

# %% [markdown]
# # Loading the data

# %%
import sys; sys.path.append('../../')
from DataPreparation.Preprocess import read_data
from DataPreparation.Visualize import convey_insights

# %%
ds,_= read_data(split="all", fix=False, handle_langs=True, handle_useless="drop")

# %%
# Extract relevant columns: primaryLanguage, languagesSizes, pullRequests
ds = ds[['primaryLanguage', 'languagesUsed', 'languagesSizes','pullRequests', 'createdAt']]

convey_insights([f"there are {ds['primaryLanguage'].nunique()} primaryLanguages"], "Number of primary programming languages")
# Out:
# <h3><font color="pink" size=5>Number of primary programming languages</font></h3> <font size=4>
# <font color="pink">✦</font> there are 401 primaryLanguages<br><br></font>

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       I expect that there are more than 250 programming languages in the dataset.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Indeed, there are 401 different primary languages in the dataset.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Expectation agrees with data.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Model Building</h2> </font>
# </span>

# %%
import Logic

import importlib
importlib.reload(Logic)

pre_processed_ds = Logic.preprocess_languages_column(ds.copy())

# %%
import Logic

# reload the module
import importlib
importlib.reload(Logic)

# get the top 3 programming languages
top_languages = Logic.get_top_k_programming_languages_over_time(pre_processed_ds, k=3)

# %%
# df_selected = top_languages[['language', 'average diskUsageKb']]
# top_languages.head()
import Logic

# reload the module
import importlib
importlib.reload(Logic)

Logic.visualize(top_languages)
# Out:
#   language  total pullRequests  average diskUsageKb
# 0     Ruby                6996           146.477959
# 1   Python                4562           340.755311
# 2      PHP                3491          5530.229492
#   language  total pullRequests  average diskUsageKb
# 0     Ruby               22027           258.843819
# 1   Python               19074           317.550836
# 2       C#               17292          3790.569003
#      language  total pullRequests  average diskUsageKb
# 0         PHP               41949           760.838432
# 1  JavaScript               23714           324.885274
# 2         C++               23267          2720.944173
#      language  total pullRequests  average diskUsageKb
# 0         C++               65829          3690.303027
# 1  JavaScript               51045           730.717785
# 2      Python               47450           335.915309
#      language  total pullRequests  average diskUsageKb
# 0  JavaScript               71779           522.006692
# 1      Python               62840           220.219154
# 2        Java               39611           813.165166
#      language  total pullRequests  average diskUsageKb
# 0  JavaScript              103181           444.694706
# 1      Python               89442           240.671591
# 2        Java               59113           973.660421
#      language  total pullRequests  average diskUsageKb
# 0  JavaScript              110283           562.797935
# 1      Python               97265          1178.638310
# 2  TypeScript               58764          4498.850648
#      language  total pullRequests  average diskUsageKb
# 0  JavaScript              126258           386.596370
# 1      Python               91119           431.067484
# 2        Java               80022           627.314947
#      language  total pullRequests  average diskUsageKb
# 0  JavaScript              140154           478.147744
# 1  TypeScript               99622           384.324886
# 2      Python               76816           249.007810
#      language  total pullRequests  average diskUsageKb
# 0  JavaScript              142058           429.711185
# 1  TypeScript              129276           228.588602
# 2      Python              100283           328.701280
#      language  total pullRequests  average diskUsageKb
# 0  TypeScript              190807           195.116009
# 1  JavaScript              163448           588.363640
# 2      Python               87577           436.240670
#      language  total pullRequests  average diskUsageKb
# 0  TypeScript              200132           219.117021
# 1  JavaScript              118253           532.058278
# 2      Python               87404           342.874622
#      language  total pullRequests  average diskUsageKb
# 0  TypeScript              136940           233.004756
# 1      Python               54792           309.784243
# 2  JavaScript               54140           432.169484
#      language  total pullRequests  average diskUsageKb
# 0  TypeScript               55772           233.641873
# 1  JavaScript               26850           386.038027
# 2      Python               24511           424.972844
#      language  total pullRequests  average diskUsageKb
# 0         C++                 376         10506.259202
# 1      Python                 264          1160.202644
# 2  JavaScript                 252           144.095323

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       It's expected that the model will get the correct answer.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#         The top 3 programming languages with their corresponding repositries' avg. sizes are shown in the table above.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#         Results seems resonable.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Results & Interpretation</h2> </font>
# </span>

# %%
convey_insights([
    "",
], "Top 3 programming languages with respect to pull requests")

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Its as expected
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       This is my data
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Suppose data is expectations; done.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Communicating Results</h2> </font>
# </span>

# %%
### Probably code that will generate markdown

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Its as expected
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       This is my data
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Suppose data is expectations; done.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>
