# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="yellow"> <h1> Databases </font> &Frameworks </h1>
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Stating Questions </h2> </font>
# </span>

# %% [markdown]
# <span style="font-family:Avenir; font-size:1.4em;">
# ✦ What <font color="Cyan">front-end frameworks</font> tend to occur most often with the <font weight='bold' >three most</font> <font color="Pink">frequent backend frameworks</font>?
# </span>
#
# <br>
#
# <span style="font-family:Avenir; font-size:1.4em;">
# ✦ What <font color="Cyan">databases</font> tend to occur more often with different <font color="Pink">backend frameworks</font>?
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       The questions is interesting and answerable.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       it is defintely will help developers to know what are the common bundle between frameworks and databases so learners can stick to the most common bundle.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Both are matching
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %%
import importlib
import Logic
Logic = importlib.reload(Logic)
import sys; sys.path.append('../../')
from DataPreparation.Preprocess import read_data
from DataPreparation.Visualize import convey_insights

# %%
ds,_= read_data(split="all", fix=False, handle_langs=True, handle_useless="all-except-description")
ds = ds[['description','primaryLanguage','languagesUsed']]

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Exploratory Data Analytics</h2> </font>
# </span>

# %%
new_ds = Logic.extend_dataset_with_frameworks(ds)

# %% [markdown]
# ### What are the backend frameworks used by developers?

# %%
Logic = importlib.reload(Logic)
Logic.explore_technology(new_ds,'back_end', top_n=7, title="Back End Frameworks")

# %% [markdown]
# ### What are the frontend frameworks used by developers?

# %%
Logic = importlib.reload(Logic)
Logic.explore_technology(new_ds,'front_end', top_n=4, title= "Front End Frameworks")

# %% [markdown]
# ### What are the databases used by developers?

# %% [markdown]
# #### SQL Databases

# %%
Logic = importlib.reload(Logic)
Logic.explore_technology(new_ds,'sql', top_n=5, title="SQL Databases")

# %% [markdown]
# #### NoSQL Databases

# %%
Logic = importlib.reload(Logic)
Logic.explore_technology(new_ds,'no_sql', top_n=5, title="NoSQL Databases")

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       I Expect that the exploratory data analysis will reveal the percentage of each framework/database and the dataset at hand covers variety of them
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Indeed, the dataset covers a variety of frameworks and databases
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Expectations are met
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Model Building</h2> </font>
# </span>

# %% [markdown]
# <span style="font-family:Avenir; font-size:1.4em;">
# ✦ What <font color="Cyan">databases</font> tend to occur more often with different <font color="Pink">backend frameworks</font>?
# </span>

# %%
back_to_front = Logic.get_front_ends_for_top_3_back_ends(new_ds)

# %%
Logic.show_histogram(back_to_front)
# Out:
# /home/ahmed/CMP/Semester 2/DS/PROJECT/Github-Metadata-Analytics/Questions/E - Database & Frameworks Correspondence/Logic.py:258: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ahmed/CMP/Semester 2/DS/PROJECT/Github-Metadata-Analytics/Questions/E - Database & Frameworks Correspondence/Logic.py:258: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ahmed/CMP/Semester 2/DS/PROJECT/Github-Metadata-Analytics/Questions/E - Database & Frameworks Correspondence/Logic.py:258: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# <span style="font-family:Avenir; font-size:1.4em;">
# ✦ What <font color="Cyan">databases</font> tend to occur more often with different <font color="Pink">backend frameworks</font>?
# </span>

# %%
import Logic
Logic = importlib.reload(Logic)
Logic.show_backend_databases_heatmap(new_ds)

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       The model will be able to show the co-occurrence of frameworks and databases
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Data is as shown
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Of course, the model is able to show the co-occurrence of frameworks and databases demonstrating where the most common bundles
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Results & Interpretation</h2> </font>
# </span>

# %%
convey_insights([
    'The top 3 back end frameworks are: Express, Ruby, and Spring',
    'React is the most used front end framework no matter what back end framework is used',
    'Express + React is a the most common combination',
],"Front End Frameworks used with the top 3 back end frameworks")

convey_insights([
    'The sample at hand shows that express is the most used back end framework',
    "Also it's easy that express is mostly used with NOSQL databases",
    "The matrix the shows the co-occurrence of backends and NOSQL is peaked at express and mongoDB",
    "The matrix the shows the co-occurrence of backends and SQL is more spread out",
],"Back End Frameworks used with SQL and NoSQL Databases")
# Out:
# <h3><font color="pink" size=5>Front End Frameworks used with the top 3 back end frameworks</font></h3> <font size=4>
# <font color="pink">✦</font> The top 3 back end frameworks are: Express, Ruby, and Spring<br><br><font color="pink">✦</font> React is the most used front end framework no matter what back end framework is used<br><br><font color="pink">✦</font> Express + React is a the most common combination<br><br></font>
# <h3><font color="pink" size=5>Back End Frameworks used with SQL and NoSQL Databases</font></h3> <font size=4>
# <font color="pink">✦</font> The sample at hand shows that express is the most used back end framework<br><br><font color="pink">✦</font> Also it's easy that express is mostly used with NOSQL databases<br><br><font color="pink">✦</font> The matrix the shows the co-occurrence of backends and NOSQL is peaked at express and mongoDB<br><br><font color="pink">✦</font> The matrix the shows the co-occurrence of backends and SQL is more spread out<br><br></font>

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       I expect that React will dominate the frequency among other frameworks as it's powered by Meta.
#       I also expect that Express will be the most common backend framework as it's a Node.js framework and Node.js is a runtime environment for JavaScript (The most popular programming language).
#       Hence, I expect the most common bundle to be React-Express.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Data is as shown
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Expectations are met perfectly
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       I expect that Express will dominate the frequency among other frameworks as justified earlier.
#       I expect Mongo and Express to be the most common bundle due to the seamless integration between the two.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Data is as shown
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Expectations are met perfectly
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Communicating Results</h2> </font>
# </span>

# %%
convey_insights([
    'There are high opportunties for developers who know React and Express',
    'The market is concentrated on a few back end frameworks like Express, Ruby, and Spring',
    'The market is concentrated on a few front end frameworks like React, Angular, and Vue',
    'Novoice developers interested in joining the market should stick to these common backend-frontend bundles',
],"Front End Frameworks used with the top 3 back end frameworks")

convey_insights([
    'There are high opportunties for developers who know MongoDB and Express',
    'For beginners who want to learn a Nosql database, MongoDB seems a rational choice',
    'The variance of sql databases is greater than nosql databases',
],"Back End Frameworks used with SQL and NoSQL Databases")
# Out:
# <h3><font color="pink" size=5>Front End Frameworks used with the top 3 back end frameworks</font></h3> <font size=4>
# <font color="pink">✦</font> There are high opportunties for developers who know React and Express<br><br><font color="pink">✦</font> The market is concentrated on a few back end frameworks like Express, Ruby, and Spring<br><br><font color="pink">✦</font> The market is concentrated on a few front end frameworks like React, Angular, and Vue<br><br><font color="pink">✦</font> Novoice developers interested in joining the market should stick to these common backend-frontend bundles<br><br></font>
# <h3><font color="pink" size=5>Back End Frameworks used with SQL and NoSQL Databases</font></h3> <font size=4>
# <font color="pink">✦</font> There are high opportunties for developers who know MongoDB and Express<br><br><font color="pink">✦</font> For beginners who want to learn a Nosql database, MongoDB seems a rational choice<br><br><font color="pink">✦</font> The variance of sql databases is greater than nosql databases<br><br></font>

# %% [markdown]
# <span style="font-family:Avenir;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Professor & TA will appreciate and be interested in the communicated information.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       As above.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Will be known after the presentation day.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>
