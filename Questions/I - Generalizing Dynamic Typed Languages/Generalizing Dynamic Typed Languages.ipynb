# %% [markdown]
# <span style="font-family:Avenir;">
# <h1> <font color="yellow"> Generalizing </font>  <font color="pink"> Dynamic Typed </font> Languages </h1>
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Stating Questions </h2> </font>
# </span>

# %% [markdown]
# <span style="font-family:; font-size:1.4em;">
# ✦ Does the <font color="yellow">popularity</font> of <font color="Pink">Javascript</font> generalize to prove that
# <font color="Pink">dynamically </font>typed languages are <font color="Cyan">more popular</font> than <font color="Pink">statically</font>
# typed ones?
# </span>

# %% [markdown]
# <span style="font-family:;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       The question discusses interesting phenomena and tries to reveal if really dynamically typed languages are more popular than statically typed ones based on the popularity of Javascript.
#       I expect that there is no explict answer for such question.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       After a little searching over internet, there is not explict answer for such question
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Expectations and data are matched
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Exploratory Data Analytics</h2> </font>
# </span>

# %%
import pandas as pd
import scipy.stats as stats
import numpy as np
import importlib
import Logic
Logic = importlib.reload(Logic)
import sys; sys.path.append('../../')
from DataPreparation.Preprocess import read_data
from DataPreparation.Visualize import convey_insights

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="pink"> <h4> Loading Data </h4> </font>
# </span>

# %%
# ds,_= read_data(split="all", fix=True, handle_langs=True, handle_useless="all") # uncomment this line if you will read the unprocessed dataset
ds = pd.read_csv('dataset-Generalizing Dynamic Programming Langs.csv')
# ds = ds[['primaryLanguage','languagesUsed', 'createdAt']]                       # uncomment this line if you will read the unprocessed dataset
# ds = Logic.preprocess_dataset(ds)                                               # uncomment this line if you will read the unprocessed dataset
ds.head()
# Out:
#   primaryLanguage                                      languagesUsed  year  \
# 0      TypeScript  ['TypeScript', 'JavaScript', 'CSS', 'Shell', '...  2014
# 1           Astro       ['Astro', 'JavaScript', 'TypeScript', 'CSS']  2017
# 2          Python                                ['Python', 'Shell']  2016
# 3          Python                                ['Python', 'Shell']  2017
# 4      TypeScript  ['TypeScript', 'JavaScript', 'HTML', 'CSS', 'S...  2013
#
#    month
# 0     12
# 1      3
# 2      3
# 3      2
# 4      7

# %% [markdown]
# <span style="font-family:;">
# <h3> Top <font color='yellow'>5</font> <font color="pink"> dynamically typed </font> programming languages </h3>
# </span>

# %%
Logic = importlib.reload(Logic)
Logic.display_circles(Logic.sort_languages(ds,Logic.dynamic_languages))

# %% [markdown]
# <span style="font-family:;">
# <h3> Top <font color='yellow'>5</font> <font color="pink"> statically typed </font> programming languages </h3>
# </span>

# %%
Logic = importlib.reload(Logic)
Logic.display_circles(Logic.sort_languages(ds,Logic.static_languages))

# %% [markdown]
# <span style="font-family:;">
# <font color="pink"> <h3> JavaScript is really a popular programming language? </h3> </font>
# </span>

# %%
Logic = importlib.reload(Logic)
langs, freqs = Logic.get_frequncy_of_languages(ds)
Logic.show_pie(langs, freqs, "Frequency of each language in the dataset")

# %% [markdown]
# <span style="font-family:;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       I expect JavaScript to be the most popular programming language as stated in the question
#       I expect that dynamically typed languages and statically typed language are represented in the dataset adequately.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       After doing a descriptive analysis the data is as shown above.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Expectations and data are matched
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Model Building</h2> </font>
# </span>

# %%
Logic = importlib.reload(Logic)
_, dynamic_freqs = Logic.get_frequncy_of_languages(ds, kind='dynamic')
_, static_freqs  = Logic.get_frequncy_of_languages(ds, kind='static')
Logic.show_pie(['dynamic','static'], [sum(dynamic_freqs), sum(static_freqs)], "Frequency of dynamic and static languages in the dataset")

# %%
Logic = importlib.reload(Logic)
dynamic_datasets, static_datasets = Logic.split_dataset_across_years(ds)
Logic.show_pie_chart_for_each_year(dynamic_datasets, static_datasets)

# %% [markdown]
# <span style="font-family:;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       I expect that the model will be able to present the usage of each type of programming language.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Data is as shown above
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Yes, the model is able to present the usage of each type of programming language in a pie chart.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Results & Interpretation</h2> </font>
# </span>

# %%
convey_insights([
    "Dynamic languages are more popular than static languages and the reason is that they are easier to use and because they appeared as an super cool innovation which prevent the hassle the developers faced at the eariler days of programming specially in the 90s",
    "Static typing is increasing in popularity over the years as the world realized the dark side of dynamic languages which is the lack of type checking which leads to many bugs and errors so they started to use more clean and neat languages like Java and C# which are definitely easier than C++ and C",
],"Dynamic vs Static Languages")
# Out:
# <h3><font color="pink" size=5>Dynamic vs Static Languages</font></h3> <font size=4>
# <font color="pink">✦</font> Dynamic languages are more popular than static languages and the reason is that they are easier to use and because they appeared as an super cool innovation which prevent the hassle the developers faced at the eariler days of programming specially in the 90s<br><br><font color="pink">✦</font> Static typing is increasing in popularity over the years as the world realized the dark side of dynamic languages which is the lack of type checking which leads to many bugs and errors so they started to use more clean and neat languages like Java and C# which are definitely easier than C++ and C<br><br></font>

# %% [markdown]
# <span style="font-family:;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       I expected that results are interpretable and there are resonable explanations for the results.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Here are the results and explanations.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Indeed, the interpretations are logical and reasonable.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:Avenir;">
# <font color="LavenderBlush"> <h2> Communicating Results</h2> </font>
# </span>

# %%
convey_insights([
    'Over history, dynamic languages are more used than static languages',
    'The usage of dynamic languages is increasing over time',
    'The world is not biased towards dynamic languages in absolute terms, in fact the popularity of both types is changing over time due to external factors like the requirements of the market and the needs of the developers'
],'Dynamic Languages vs Static Languages')
# Out:
# <h3><font color="pink" size=5>Dynamic Languages vs Static Languages</font></h3> <font size=4>
# <font color="pink">✦</font> Over history, dynamic languages are more used than static languages<br><br><font color="pink">✦</font> The usage of dynamic languages is increasing over time<br><br><font color="pink">✦</font> The world is not biased towards dynamic languages in absolute terms, in fact the popularity of both types is changing over time due to external factors like the requirements of the market and the needs of the developers<br><br></font>

# %% [markdown]
# <span style="font-family:;">
#
# <table style="width:100%; border-collapse:collapse; table-layout:fixed;">
#   <thead>
#     <tr>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Set Expectations</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Collect Data</font>
#       </th>
#       <th style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       <font color="DeepSkyBlue">Match Expectations & Data</font>
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Professor & TA will appreciate and be interested in the communicated information.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       As above.
#       </td>
#       <td style="padding:10px; border:0.5px solid grey; text-align: center; width:33.33%;">
#       Will be known after the presentation day.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# </span>

# %% [markdown]
# <span style="font-family:;">
# <font color="yellow"> <h2> Hypothesis </font> <font color='pink'> Testing </font></h2>
# </span>

# %% [markdown]
# <span style="font-family:;">
# <font color="Yellow"> <h3>Hypothesis: </font> The average usage of <font color='pink'>dynamically typed </font>programming languages is greater than the average usage of <font color='pink'>statically typed</font> ones</h3>
# </span>

# %% [markdown]
# ## T-Test

# %%
Logic = importlib.reload(Logic)
dynamic_datasets, static_datasets = Logic.split_dataset_across_years_months(ds)


dynamic_usage = [(year, month, len(dynamic_datasets[year][month])) for year in dynamic_datasets.keys() for month in dynamic_datasets[year].keys()]
static_usage = [(year, month, len(static_datasets[year][month])) for year in static_datasets.keys() for month in static_datasets[year].keys()]

dynamic_usage.sort(key=lambda x: (x[0], x[1]))
static_usage.sort(key=lambda x: (x[0], x[1]))

dynamic_usage = [x[2] for x in dynamic_usage]
static_usage = [x[2] for x in static_usage]

#Perform independent samples t-test
t_stat, p_value = stats.ttest_ind(dynamic_usage, static_usage, alternative='greater')

alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis (H0) in favor of the alternative hypothesis (Ha)")
    print("Average usage of dynamic programming languages is significantly greater than the average usage of static programming languages.")
else:
    print("Fail to reject the null hypothesis (H0)")
    print("Average usage of dynamic programming languages is not significantly greater than the average usage of static programming languages.")
# Out:
# Reject the null hypothesis (H0) in favor of the alternative hypothesis (Ha)
# Average usage of dynamic programming languages is significantly greater than the average usage of static programming languages.

# %%
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 7.3855959637198945
# p-value: 5.379488410555748e-13

# %% [markdown]
# ## Z-Test

# %%
dynamic_mean = np.mean(dynamic_usage)
static_mean = np.mean(static_usage)
dynamic_std = np.std(dynamic_usage)
static_std = np.std(static_usage)

# Calculate the standard error of the difference between the means
n1 = len(dynamic_usage)
n2 = len(static_usage)
standard_error = np.sqrt((dynamic_std**2 / n1) + (static_std**2 / n2))

# Perform z-test
z_stat = (dynamic_mean - static_mean) / standard_error
p_value = 1 - stats.norm.cdf(z_stat)

alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis (H0) in favor of the alternative hypothesis (Ha)")
    print("Average usage of dynamic programming languages is significantly greater than the average usage of static programming languages.")
else:
    print("Fail to reject the null hypothesis (H0)")
    print("Average usage of dynamic programming languages is not significantly greater than the average usage of static programming languages.")
# Out:
# Reject the null hypothesis (H0) in favor of the alternative hypothesis (Ha)
# Average usage of dynamic programming languages is significantly greater than the average usage of static programming languages.

# %%
print("z-statistic:", z_stat)
print("p-value:", p_value)
# Out:
# z-statistic: 7.406197387179151
# p-value: 6.494804694057166e-14

# %% [markdown]
# ## Proporition Test

# %%
import statsmodels.api as sm

dynamic_total = sum(dynamic_usage)
static_total = sum(static_usage)

dynamic_proportion = dynamic_total / (dynamic_total + static_total)
static_proportion = static_total / (dynamic_total + static_total)

# Perform proportion test
successes = [dynamic_total, static_total]
totals = [dynamic_total + static_total, dynamic_total + static_total]
z_stat, p_value = sm.stats.proportions_ztest(successes, totals, alternative='larger')

alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis (H0) in favor of the alternative hypothesis (Ha)")
    print("Dynamic programming languages are more popular than static programming languages.")
else:
    print("Fail to reject the null hypothesis (H0)")
    print("There is insufficient evidence to suggest that dynamic programming languages are more popular than static programming languages.")
# Out:
# Reject the null hypothesis (H0) in favor of the alternative hypothesis (Ha)
# Dynamic programming languages are more popular than static programming languages.
